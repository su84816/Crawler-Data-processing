# %%
import requests
import codecs

url = 'http://teaching.bo-yuan.net/'
#requests主要用法,加入更多header資訊可以騙過server,減少被檔
r1 = requests.get(url,
  #用網址切一下可以得到兩個變數 ##原網址：http://teaching.bo-yuan.net/?uid=615d3746bc173&id=5f81d9e038e6b_ex ###這是動態網頁,每個人的網址不一樣
  params={
      # 'uid':'615d3746bc173',
      # 'id':'5e81faa6afa30_ex'
      'uid':'615d3746bc173',
      'id':'5f81d9e038e6b_ex'
  },
  headers={
      'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:93.0) Gecko/20100101 Firefox/93.0',
      'Cookie':'PHPSESSID=395khk6qpafgne4c75nf98o4j2'
      #cookie一定要!!!!!!
  }
                  )

with codecs.open('/content/drive/MyDrive/AI_02/3_2.pdf','wb') as f: #這裡因為二進位制,w後面+b,不用再加編碼
  f.write(r1.content) #因為是二進位制所以要用content要用content

# %%
from google.colab import drive #雲端存檔,只要做一次 ##如果你是新的程式要再連一次(run這段)或是你是閒置一段時間要再run一次
drive.mount('/content/drive') #drive.mount("/content/drive")先寫,執行,會要求你驗證
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
