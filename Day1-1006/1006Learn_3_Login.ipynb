# %%
import requests
import codecs
#post練習
url = 'http://teaching.bo-yuan.net/'
#requests主要用法,加入更多header資訊可以騙過server,減少被檔
r1 = requests.post(url, #改post
  #用網址切一下可以得到兩個變數 #(要先登出)在登入時輸入帳號密碼,再擷取裡面的檢測資訊
  #http://teaching.bo-yuan.net/?uid=615d37148e36d
  params={
      'uid':'615d37148e36d',
  },
  headers={
      'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:93.0) Gecko/20100101 Firefox/93.0',
      'Cookie':'PHPSESSID=8oatci9v2dftuibvfltv95dd7o'#cookie一定要!!!!!!
  },
  #從請求裡面找到登入介面的原始碼,用字典寫進 ###完成後登出,run程式後他就會自動登入(等於用程式登入),因為程式&網頁上的cookie紀錄是相同的
  #驗證碼就是在檔post的爬蟲
  data={
      "ex[class]":"6152b2f312151",
      "ex[username]":"15蘇羣",
      "ex[password]":"322d7f"
  }
                  )

# %%
# Out:
# Mounted at /content/drive
