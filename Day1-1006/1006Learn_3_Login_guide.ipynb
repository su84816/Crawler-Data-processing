# %%
import requests
import codecs
#post練習
url = 'http://teaching.bo-yuan.net/'
#requests主要用法,加入更多header資訊可以騙過server,減少被檔
r1 = requests.post(url, #改get>post
  #用網址切一下可以得到一個變數(uid) #(要先登出)在登入時輸入帳號密碼,再擷取裡面的檢測資訊(開著f12進行輸入+登入)
  #http://teaching.bo-yuan.net/?uid=????? ##?????這裡要看你登入的網址
  params={
      'uid':'?????', #?????放你的uid,在f12的標頭可以找到
  },
  headers={
      'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:93.0) Gecko/20100101 Firefox/93.0',
      'Cookie':'?????'#cookie放你cookie的值,在f12的標頭可以找到
  },
  #從"請求"裡面找到登入介面的原始碼,用字典寫進 ###完成後登出,run程式後他就會自動登入(等於用程式登入),因為程式&網頁上的cookie紀錄是相同的
  data={
      "ex[class]":"?????", #班級號碼 我們應該是一樣的
      "ex[username]":"?????", #?????=你的帳號
      "ex[password]":"?????" #?????=你的密碼
  }
                  )

# %%
# Out:
# Mounted at /content/drive
